# %%
print("hello world")
# Out:
# hello world

# %%
first pandas code

# %%
import pandas as pd
student={
    "name":["ghaydaa","lubna","sara"],
    "age":[22,23,24],
    "major":["cs","nurse","dr"]
}
df=pd.DataFrame(student)

print(df)
# Out:
#       name  age  major
# 0  ghaydaa   22     cs
# 1    lubna   23  nurse
# 2     sara   24     dr

# %% [markdown]
# first numpy code

# %%
import numpy as np
arr1=np.array([1,2,3,4])
arr2=np.array([[1,2],[3,4],[5,6]])
print(arr1)
print(arr2)
# Out:
# [1 2 3 4]
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
import matplotlib.pyplot as plt
import pandas as pd
student={
    "name":["ghaydaa","lubna","sara"],
    "age":[22,23,24],
}
df=pd.DataFrame(student)

print(df)
plt.bar(df["name"], df["age"])
plt.show()
# Out:
#       name  age
# 0  ghaydaa   22
# 1    lubna   23
# 2     sara   24

# %%
import matplotlib.pyplot as plt
import pandas as pd
student={
    "name":["ghaydaa","lubna","sara"],
    "age":[22,23,24],
}
df=pd.DataFrame(student)

print(df)
plt.scatter(df["name"], df["age"])
plt.show()
# Out:
#       name  age
# 0  ghaydaa   22
# 1    lubna   23
# 2     sara   24
