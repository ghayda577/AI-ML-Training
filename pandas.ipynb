# %% [markdown]
# # Exploring a Real Dataset with Pandas

# %% [markdown]
# ## Step 1: Load the Dataset
#
# I loaded the Titanic dataset and explored its structure by finding the shape, columns, and data types.

# %%
import pandas as pd
df = pd.read_csv("Titanic-Dataset.csv")
print("Shape :",df.shape)
print("Columns :", df.columns)
print("Data type :", df.dtypes)
# Out:
# Shape : (891, 12)
# Columns : Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')
# Data type : PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %% [markdown]
# ## Step 2: Count missing values per column and handle them (fill or drop) with a documented justification.

# %% [markdown]
# ### Numbers of missing values

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Fill the missing values
#
# I chose to fill the missing values in the "Cabin" column instead of dropping them because dropping this column would result in losing valuable information from the dataset.

# %%
df1["Cabin"]=df1["Cabin"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\MOSAB PC\AppData\Local\Temp\ipykernel_23916\161914060.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df1["Cabin"]=df1["Cabin"].fillna("Unknown", inplace=True)

# %% [markdown]
# ### Verify the results

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %% [markdown]
#  ### repeat the same steps for the age column

# %%
df1["Age"] = df1["Age"].fillna(df1["Age"].mean())

# %%
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %% [markdown]
# ## Step 3: Filter the Data
# Filter the dataset to include only adult passengers (Age > 17).

# %%
filteres_age=df[df["Age"] > 17]
print("Number of adult passengers:", len(filteres_age))
# Out:
# Number of adult passengers: 601

# %% [markdown]
# ### Analysis
#
# The dataset was filtered to include only adult passengers (Age> 17). After filtering, there were 601 adult passengers. This subset can be used to analyze the characteristics of adult passengers, such as their survival rate, passenger class, and ticket fare.

# %% [markdown]
# ## step 4: GroupBy Analysis

# %% [markdown]
# ### Average Age by Gender
#
# I used groupby to divide the Titanic passengers based on their gender and calculated the average age for each group.

# %%
df1.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    28.216730
# male      30.505824
# Name: Age, dtype: float64

# %% [markdown]
# ### Survival Rate and Maximum Age by Gender
#
# I used groupby with aggregation to analyze passengers based on gender.
# I calculated the maximum age and the average survival rate for each gender group. The survival rate shows the proportion of passengers who survived in each group, where a higher value indicates a greater chance of survival.

# %%
df1.groupby("Sex").agg({"Age":"max",
"Survived":"mean"})
# Out:
#          Age  Survived
# Sex
# female  63.0  0.742038
# male    80.0  0.188908
